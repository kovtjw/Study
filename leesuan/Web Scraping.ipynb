# %% [markdown]
# # 웹 스크래핑
# HTTP를 통햬 웹 사이트의 내용을 긁어, 원하는 형태로 가공하는 것
# 웹 사이트의 데이터를 수집하는 모든 작업을 의미

# %% [markdown]
# # 크롤링
# 웹 크롤러에서 유래, 조직적, 자동화된 방법으로 월드와이드웹을 탐색하는 프로그램
# 찾아낸 데이터를 저장한 후 쉽게 찾을 수 있게 인덱싱 수행
#
# # 파싱
# 어떤 페이지(문서, html 등)에서 내가 원하는 데이터를 특정 패턴이나 순서로 추출하여 정보를 가공하는 것
# 일련의 문자열을 의미있는 토큰으로 분해하고 이들로 이루어진 파스트리를 만드는 과정
# 입력 토근에 내제된 자료 구조를 빌드하고 문법을 검사하는 역할을 함

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "gTqNaqyjog14g27TrawW"
client_secret = "VrNLxqvvkm"
encText = urllib.parse.quote("강남 맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 06 Jan 2022 17:51:17 +0900",
# "total": 1219303,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "매력적이었던 <b>강남 맛집</b> 리스트",
# "link": "https:\/\/blog.naver.com\/beta2260?Redirect=Log&logNo=222588554941",
# "description": "들어가기 전의 기대감보다 나올 때의 만족감이 더 높았던 <b>강남 맛집</b>. 3가지 요리가 모두 만족스러워서 다음에 꼭 재방문 해 보려고요. 2. 구전동화 전화 : 02-512-0991 주소 : 서울 강남구 압구정로 46길 26... ",
# "bloggername": "반짝이는 일상 ♡",
# "bloggerlink": "https://blog.naver.com/beta2260",
# "postdate": "20211206"
#
# },
# {
# "title": "추천하고픈 <b>강남</b> 코엑스 <b>맛집</b> 리스트",
# "link": "https:\/\/blog.naver.com\/cebuhopping?Redirect=Log&logNo=222612688689",
# "description": "친구들이랑 <b>강남</b> 코엑스에서 <b>강남</b> 코엑스 <b>맛집</b> 들러봤는데요. 기억에 남는 곳들로 소개드려볼게요. 꼭 추천하고픈 곳들로 만든 리스트에요. 삼성역 5번 출구에서 533m 떨어진 <b>강남</b> 코엑스몰 지하 1층에 자리잡은... ",
# "bloggername": "제주호핑투어",
# "bloggerlink": "https://blog.naver.com/cebuhopping",
# "postdate": "20220104"
#
# },
# {
# "title": "실패없던 <b>강남 맛집</b>",
# "link": "https:\/\/blog.naver.com\/ssong920?Redirect=Log&logNo=222535105753",
# "description": "친절한 서비스는 물론 색다른 요리를 선보여준 <b>강남 맛집</b>이라 종종 찾을 것 같아요. 2. 카멜커피 메뉴 : 카멜커피 5,500원 주소 : 서울 강남구 도산대로45길 16-8 번호 : ***-****-**** 시간 : 매일 10:00 - 21:00 연중무휴... ",
# "bloggername": "H A F F Y H A A : L O G",
# "bloggerlink": "https://blog.naver.com/ssong920",
# "postdate": "20211012"
#
# },
# {
# "title": "강렬했던 <b>강남 맛집</b> 소개",
# "link": "https:\/\/blog.naver.com\/lightsout?Redirect=Log&logNo=222460109605",
# "description": "엊그제 친하게 지내는 형님과 약속이 있어 강남쪽에 갔다가 미리 찾아둔 <b>강남 맛집</b>을 방문했습니다. 카오위라는 다소 낯선 중국음식을 전문으로 하는 곳이었는데 화끈한 마라 맛이 일품이었기에... ",
# "bloggername": "UltraOrange's Light Illusion",
# "bloggerlink": "https://blog.naver.com/lightsout",
# "postdate": "20210807"
#
# },
# {
# "title": "정성 가득한 한정식 <b>강남</b> 점심 <b>맛집</b> 공유",
# "link": "https:\/\/blog.naver.com\/almost_s?Redirect=Log&logNo=222602796634",
# "description": "부모님도 좋아할 것 같아 조만간 노랑저고리에 또 방문하고싶습니다. #<b>강남</b>점심<b>맛집</b> #<b>강남</b>한정식 #노랑저고리 이포스팅은 해당업체로부터 소정의 원고료를 받아 작성되었습니다.",
# "bloggername": "공간디자이너의 여행하는 삶",
# "bloggerlink": "https://blog.naver.com/almost_s",
# "postdate": "20211224"
#
# },
# {
# "title": "강남고기집 신논현 <b>강남 맛집</b> 영동그집",
# "link": "https:\/\/blog.naver.com\/kjh90530?Redirect=Log&logNo=222512576312",
# "description": "신논현 <b>맛집</b> 영동그집 <b>강남</b> 고기집으로 핫한 영동그집 다녀왔다. 2주이상 숙성시킨 고기라고 하는데, 정말 기대 됐다! 일반 고기집이랑은 다르게 세련됐다. 연인끼리 또는 부모님이랑 와도 좋겠다. 고기 맛도... ",
# "bloggername": "Hello Stranger",
# "bloggerlink": "https://blog.naver.com/kjh90530",
# "postdate": "20210921"
#
# },
# {
# "title": "<b>강남</b> 김치찌개 <b>맛집</b> 지안정 뜨끈한 기분을 즐겨요",
# "link": "https:\/\/blog.naver.com\/magnolia707?Redirect=Log&logNo=222589692748",
# "description": "이번에 가본 지안정은 추운 날 얼큰하고 따끈한 국물이 끌릴 때, 한 번쯤 가볼 만한 곳이라는 그런 생각이 드는 곳이에요. 언젠가 또 가봤으면 좋겠네요. #지안정 #강남김치찌개 #<b>강남맛집</b> #강남김치찌개맛집",
# "bloggername": "나의 즐거운 이야기",
# "bloggerlink": "https://blog.naver.com/magnolia707",
# "postdate": "20211208"
#
# },
# {
# "title": "별났던 <b>강남 맛집</b> 소개",
# "link": "https:\/\/blog.naver.com\/happylife_mi?Redirect=Log&logNo=222514726234",
# "description": "유명한 <b>강남 맛집</b>에 모였어요. 재료가 다양해서 먹는 내내 물림이 없었고, 가성비도 출중했던 곳이라 소개해볼까 한답니다. 1. 바비레드 메뉴: 바비 스테이크 22,000원 주소: 서울 강남구 봉은사로6길 39 번호: 02... ",
# "bloggername": "동팔이의 즐거운상삶",
# "bloggerlink": "https://blog.naver.com/happylife_mi",
# "postdate": "20210924"
#
# },
# {
# "title": "대박이었던 <b>강남 맛집</b> 리스트",
# "link": "https:\/\/blog.naver.com\/font21?Redirect=Log&logNo=222465962168",
# "description": "알아본 <b>강남 맛집</b>에 다녀왔어요. 고급스러운 이탈리안 피자를 종류별로 즐긴 곳이라 소개합니다. 1. 도치피자 디아볼라 19,500원 / 시저샐러드 16,500원 주소 : 서울 강남구 강남대로98길 27 전화번호 : 02-556-8001... ",
# "bloggername": "적절한 먹을거리 탐방",
# "bloggerlink": "https://blog.naver.com/font21",
# "postdate": "20210811"
#
# },
# {
# "title": "일원역 <b>맛집</b> <b>강남</b>에서 퇴근 후 단체모임 가지기 좋은 핫플... ",
# "link": "https:\/\/blog.naver.com\/zoa0403?Redirect=Log&logNo=222607780399",
# "description": "#신의주찹쌀순대일원점#<b>강남맛집</b>#강남국맛집#대청역맛집#일원동맛집#일원역맛집#삼성서울병원맛집#일원동순대국#강남구해장#강남회식#일원동밥집#대청역점심#강남핫플#강남데이트#강남국밥#강남모임... ",
# "bloggername": "조아의 성",
# "bloggerlink": "https://blog.naver.com/zoa0403",
# "postdate": "20211229"
#
# }
# ]
# }

# %%
import re
import json
import math
import requests
import urllib.request
import urllib.error
import urllib.parse
from bs4 import BeautifulSoup

naver_client_id = "gTqNaqyjog14g27TrawW"
naver_client_secret = "VrNLxqvvkm"

def get_blog_count(query, display):
    encode_query = urllib.parse.quote(query)
    search_url = "https://openapi.naver.com/v1/search/blog?query=" + encode_query
    request = urllib.request.Request(search_url)

    request.add_header('X-NAVER-CLIENT-ID', naver_client_id)
    request.add_header('X-NAVER-CLIENT-PW', naver_client_secret)

    response = urllib.request.urlopen(request)
    response_code = response.getcode()

    if response_code is 200:
        response_body = response.read()
        response_body_dict = json.loads(response_body.decode('utf-8'))
        
        print('Last Build date:'+ str(response_body_dict['lastBuildDate']))
        print('Total :'+str (response_body_dict['total']))
        print('Start :'+str (response_body_dict['start']))
        print('Display :'+str (response_body_dict['display']))
        
        if response_body_dict['total'] ==0:
            blog_count = 0
        else:
            blog_total = math.ceil(response_body_dict['total']/int(display))
            
            if blog_total >= 1000:
                blog_count = 1000
            else:
                blog_count = blog_total
                
            print('Blog total:' + str(blog_total))
            print('Blog count:' + str(blog_count))
            
    return blog_count
            
        
        
    

if __name__ == '__main__':
    no = 0
    query = '손흥민'
    display = 10
    start =1
    sorf = 'date'
    
    fs = open(query+'.txt', 'a', encoding='utf-8')

    blog_count = get_blog_count(query, display)

    fs.close()
# Out:
# <>:24: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:24: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_12656/1050356370.py:24: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if response_code is 200:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12656/1050356370.py in <module>
#      59     fs = open(query+'.txt', 'a', encoding='utf-8')
#      60
# ---> 61     blog_count = get_blog_count(query, display)
#      62
#      63     fs.close()
#
# ~\AppData\Local\Temp/ipykernel_12656/1050356370.py in get_blog_count(query, display)
#      19     request.add_header('X-NAVER-CLIENT-PW', naver_client_secret)
#      20
# ---> 21     response = urllib.request.urlopen(request)
#      22     response_code = response.getcode()
#      23
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 401: Unauthorized
